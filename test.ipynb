# %%
from model.user_data import fetch_admin_data, fetch_user_data

# %%
from datetime import datetime

# %%
fetch_user_data("duskygloom708@gmail.com", datetime(2026, 2, 1), datetime(2026, 2, 6))
# Out:
# {'daily': {'2026-02-01': {'avg_mood': 3.0,
#    'avg_stress': 4.0,
#    'ai_mood': 3.0,
#    'ai_stress': 3.0},
#   '2026-02-02': {'avg_mood': 0,
#    'avg_stress': 0,
#    'ai_mood': 3.0,
#    'ai_stress': 3.0},
#   '2026-02-03': {'avg_mood': 3.0,
#    'avg_stress': 1.0,
#    'ai_mood': 3.0,
#    'ai_stress': 3.0},
#   '2026-02-04': {'avg_mood': 3.0,
#    'avg_stress': 4.0,
#    'ai_mood': 3.0,
#    'ai_stress': 3.0},
#   '2026-02-05': {'avg_mood': 3.0,
#    'avg_stress': 1.0,
#    'ai_mood': 3.0,
#    'ai_stress': 3.0},
#   '2026-02-06': {'avg_mood': 2.5,
#    'avg_stress': 2.5,
#    'ai_mood': 3.0,
#    'ai_stress': 3.0}}}

# %%
fetch_admin_data(datetime(2026, 2, 1), datetime(2026, 2, 6))
# Out:
# {'total_participants': 1,
#  'pilot_duration': 1615155,
#  'daily': {'2026-02-01': {'avg_mood': 3.0,
#    'avg_stress': 4.0,
#    'participation': 1},
#   '2026-02-02': {'avg_mood': 0, 'avg_stress': 0, 'participation': 0},
#   '2026-02-03': {'avg_mood': 3.0, 'avg_stress': 1.0, 'participation': 1},
#   '2026-02-04': {'avg_mood': 3.0, 'avg_stress': 4.0, 'participation': 1},
#   '2026-02-05': {'avg_mood': 3.0, 'avg_stress': 1.0, 'participation': 1},
#   '2026-02-06': {'avg_mood': 2.5, 'avg_stress': 2.5, 'participation': 1}}}
